-- %% [markdown]
-- ##Grants

-- %%
GRANT SELECT ON TABLE catalog_dev.bronze.productos TO `amunoz.0790@outlook.com`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_dev TO `amunoz.0790@outlook.com`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `amunoz.0790@outlook.com`;

GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `Desarrolladores`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `Desarrolladores`;

-- %%
GRANT CREATE TABLE ON SCHEMA catalog_dev.bronze TO `amunoz.0790@outlook.com`;

-- %%
GRANT SELECT ON TABLE catalog_dev.bronze.productos TO `Admin`;
GRANT SELECT ON TABLE catalog_dev.silver.ventas_productos_categorias TO `Analistas`;

-- GRANT CREATE ON CATALOG catalog_dev TO `Desarrolladores`;
-- GRANT SELECT ON CATALOG catalog_dev TO `Desarrolladores`;
-- GRANT ALL PRIVILEGES ON CATALOG catalog_dev TO `Admin`;

-- %%
SHOW GRANTS ON TABLE catalog_dev.bronze.productos;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;

-- %%
SHOW GRANTS ON CATALOG catalog_dev;

-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_dev.bronze FROM `amunoz.0790@outlook.com`;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
SHOW GRANTS ON EXTERNAL LOCATION `extl-raw`

-- %%
GRANT READ FILES
ON EXTERNAL LOCATION `extl-raw`
TO `amunoz.0790@outlook.com`;

-- %%
GRANT WRITE FILES
ON EXTERNAL LOCATION `extl-bronze`
TO `amunoz.0790@outlook.com`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `extl-bronze`
TO `amunoz.0790@outlook.com`;

-- %%
CREATE GROUP `data_engineers`;

-- %%
ALTER GROUP `data_engineers`
ADD USER `amunoz.0790@outlook.com`;

-- %%
SHOW USERS;
